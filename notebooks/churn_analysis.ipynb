# %%
# !pip install pymysql

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:sravani@localhost/churn_analysis"
)

# %%
pd.read_sql("SELECT 1", engine)
# Out:
#    1
# 0  1

# %%
df = pd.read_sql("SELECT * FROM customer_master", engine)
df.shape
# Out:
# (1000, 13)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'region', 'plan_type',
#        'monthly_charges', 'tenure_months', 'data_usage_gb', 'call_minutes',
#        'payment_method', 'payment_status', 'churn_flag', 'churn_date'],
#       dtype='object')

# %%
df['churn_flag'].value_counts()
# Out:
# churn_flag
# No     706
# Yes    294
# Name: count, dtype: int64

# %%
(df['churn_flag'].value_counts()['Yes'] / len(df)) * 100
# Out:
# np.float64(29.4)

# %%
df[df['churn_flag'] == 'Yes']['monthly_charges'].sum()
# Out:
# np.int64(139906)

# %%
df.groupby(['plan_type', 'churn_flag']).size().unstack()
# Out:
# churn_flag   No  Yes
# plan_type
# Basic       300   93
# Premium     171   84
# Standard    235  117

# %%
df.groupby(['region', 'churn_flag']).size().unstack()
# Out:
# churn_flag   No  Yes
# region
# East        156   69
# North       183   75
# South       183   87
# West        184   63

# %%
df.groupby('churn_flag')[['data_usage_gb', 'call_minutes']].mean()
# Out:
#             data_usage_gb  call_minutes
# churn_flag
# No              12.666289    456.983003
# Yes             12.574830    472.408163

# %%
pd.crosstab(df['payment_status'], df['churn_flag'])
# Out:
# churn_flag       No  Yes
# payment_status
# Failed          119   43
# Success         587  251

# %%
df.groupby('churn_flag')['tenure_months'].mean()
# Out:
# churn_flag
# No     30.240793
# Yes    29.948980
# Name: tenure_months, dtype: float64
